# %%
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
import numpy as np
from sklearn.metrics import accuracy_score
from torchinfo import summary
import torch.nn as nn
import argparse, os, json, sys
import matplotlib.pyplot as plt
from torch.utils.data import Dataset
import h5py
from EvalTools import *
sys.path.append("../model")
from PFINDataset import PFINDataset
from UQPFIN import UQPFIN as Model
# %env HDF5_USE_FILE_LOCKING=FALSE
# Out:
# env: HDF5_USE_FILE_LOCKING=FALSE

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
makeFile = False

# %%
saved_model_loc = "../model/trained_models/"
saved_model_dict_loc = "../model/trained_model_dicts/"
all_models = [f for f in os.listdir(saved_model_loc) if "_best" in f and "_trial" not in f]
print("\n".join(all_models))
# Out:
# UQPFIN_best_jetnet_softmax_skiptop_3
# UQPFIN_best_jetnet_softmax_skipwz_9
# UQPFIN_best_jetnet_0.1_skiptop
# UQPFIN_best_jetnet_softmax_skiptop_2
# UQPFIN_best_jetnet_nominal_skiptop
# UQPFIN_best_jetnet_0_baseline
# UQPFIN_best_jetnet_softmax_dropout_skipwz
# UQPFIN_best_jetnet_softmax_skiptwz_3
# UQPFIN_best_jetnet_softmax_skiptwz_2
# UQPFIN_best_jetnet_softmax_skipwz_3
# UQPFIN_best_jetnet_softmax_skiptop_8
# UQPFIN_best_jetnet_softmax_skipwz_0
# UQPFIN_best_jetnet_softmax_skiptwz_6
# UQPFIN_best_jetnet_0_skipwz
# UQPFIN_best_jetnet_0.5_skipwz_ocmodel
# UQPFIN_best_jetnet_softmax_skipwz_1
# UQPFIN_best_jetnet_softmax_skiptwz_5
# UQPFIN_best_topdata_0_baseline
# UQPFIN_best_topdata_0.1_ptmask575
# UQPFIN_best_jetnet_0.1_skiptwz
# UQPFIN_best_jetnet_0.5_skiptop_ocmodel
# UQPFIN_best_jetnet_softmax_skipwz_6
# UQPFIN_best_jetnet_softmax_skipwz_7
# UQPFIN_best_jetnet_softmax_skipwz_8
# UQPFIN_best_jetnet_nominal_baseline
# UQPFIN_best_jetnet_softmax_skiptop_7
# UQPFIN_best_jetnet_softmax_skiptop_5
# UQPFIN_best_topdata_nominal_baseline
# UQPFIN_best_jetnet_softmax_skiptop_0
# UQPFIN_best_jetnet_nominal_baseline2
# UQPFIN_best_jetnet_softmax_skiptwz_7
# UQPFIN_best_jetnet_softmax_dropout_skiptwz
# UQPFIN_best_jetnet_softmax_skiptop_9
# UQPFIN_best_jetnet_softmax_skiptwz_9
# UQPFIN_best_jetnet_softmax_skiptop_4
# UQPFIN_best_topdata_0.1_baseline
# UQPFIN_best_jetnet_0_skiptwz
# UQPFIN_best_jetnet_softmax_skipwz_2
# UQPFIN_best_topdata_nominal_ptmask575
# UQPFIN_best_jetnet_softmax_skiptop_1
# UQPFIN_best_topdata_0.1_massmask200
# UQPFIN_best_jetnet_nominal_skiptwz
# UQPFIN_best_jetnet_softmax_dropout_skiptop
# UQPFIN_best_jetnet_softmax_skiptwz_1
# UQPFIN_best_topdata_nominal_massmask200
# UQPFIN_best_jetnet_0.1_skipwz
# UQPFIN_best_jetnet_softmax_skipwz_5
# UQPFIN_best_jetnet_nominal_skipwz
# UQPFIN_best_jetnet_0.5_skiptwz_ocmodel
# UQPFIN_best_jetnet_softmax_skiptwz_4
# UQPFIN_best_jetnet_0_skiptop
# UQPFIN_best_jetnet_softmax_skiptop_6
# UQPFIN_best_jetnet_softmax_skiptwz_0
# UQPFIN_best_jetnet_softmax_skipwz_4
# UQPFIN_best_jetnet_0.1_baseline

# %%
# def getprobs(outs):
#     alphas = outs + 1
#     S = torch.sum(alphas, 1).reshape(-1,1)
#     return alphas / S

# def index_logic(logic, v1, v2, a):
#     if logic == 'AND':
#         keep = (a > min(v1, v2)) & (a < max(v1, v2))
#     else:
#         keep = (a < min(v1, v2)) | (a > max(v1, v2))
#     return keep

# %%
# class ModelEvaluator:
#     def __init__(self, model_path):
#         self.model_path = model_path
#         self.model_dict_path = model_path.replace("_best","").replace("_best","").replace("trained_models/", "trained_model_dicts/") + ".json"
#         self.model_dict = json.load(open(self.model_dict_path))
#         self.phi_nodes = list(map(int, self.model_dict["phi_nodes"].strip().split(',')))
#         self.f_nodes = list(map(int, self.model_dict["f_nodes"].strip().split(',')))
#         self.n_phiI = int(self.model_dict['n_phiI'])
#         self.label = self.model_dict['label']
#         self.data_type = self.model_dict['data_type']
#         self.massrange = self.model_dict['massrange']
#         self.etarange = self.model_dict['etarange']
#         self.ptrange = self.model_dict['ptrange']
#         self.x_mode = self.model_dict['x_mode']
#         self.skip_labels = self.model_dict["skiplabels"]
#         try:
#             self.use_softmax = self.model_dict["use_softmax"]
#         except:
#             self.use_softmax = False
#         try:
#             self.use_dropout = self.model_dict["use_dropout"]
#         except:
#             self.use_dropout = False
#         self.m_logic, (self.m1, self.m2) = self.massrange.strip().split(':')[0], list(map(float, self.massrange.strip().split(':')[1].split(',')))
#         self.pt_logic,(self.pt1, self.pt2) = self.ptrange.strip().split(':')[0], list(map(float, self.ptrange.strip().split(':')[1].split(',')))
#         self.eta_logic, (self.eta1, self.eta2) = self.etarange.strip().split(':')[0], list(map(float, self.etarange.strip().split(':')[1].split(',')))
        
#         if self.data_type == 'topdata':
#             Np = 60
#             self.num_classes = 2
#             self.skip_labels = []
#             self.label_indices = [0,1]
#             self.data_path = "../datasets/topdata/test.h5"
#         elif self.data_type == 'jetnet':
#             Np = 30
#             if self.skip_labels:
#                 self.skip_labels = list(map(int, self.skip_labels.strip().split(',')))
#             else:
#                 self.skip_labels = []
#             self.num_classes = 5 - len(self.skip_labels)
#             self.label_indices = [i for i in range(5) if i not in self.skip_labels]
#             self.data_path = "../datasets/jetnet/test.h5"
        
        
#         self.model = Model(particle_feats = 3,
#                            n_consts = Np,
#                            num_classes = self.num_classes,
#                            device = device,
#                            PhiI_nodes = self.n_phiI,
#                            interaction_mode = self.x_mode,
#                            use_softmax = self.use_softmax,
#                            use_dropout = self.use_dropout,
#                            Phi_sizes = self.phi_nodes,
#                            F_sizes   = self.f_nodes).to(device)
#         self.model.load_state_dict(torch.load(self.model_path))
        
#         self.model.eval()
        

        
#     def index_groomer(self, a, y):
#         keep_masses = index_logic(self.m_logic,   self.m1,   self.m2,   a[:, 1])
#         keep_pts    = index_logic(self.pt_logic,  self.pt1,  self.pt2,  a[:, 2])
#         keep_etas   = index_logic(self.eta_logic, self.eta1, self.eta2, a[:, 3])

#         keep_labels = torch.tensor(np.isin(np.argmax(y.cpu().numpy(), 1), self.skip_labels, invert=True)).bool()

#         return (keep_masses & keep_pts & keep_etas & keep_labels).bool()
    
#     def evaluate(self):
#         test_set = PFINDataset(self.data_path)
#         testloader = DataLoader(test_set, shuffle=True, batch_size=512, num_workers=8, pin_memory=True, persistent_workers=True)
#         labels = []
#         preds = []
#         maxprobs = []
#         probs = []
#         oods = []
#         sums = []
#         with torch.no_grad():
#             for x,m,a,y in tqdm(testloader, disable = True):
#                 x = x.cuda()
#                 m = m.cuda()
#                 a = a.cuda()
#                 pred = self.model(x, a, m).cpu()
#                 idx2keep = self.index_groomer(a.cpu(), y).cpu().numpy()
#                 if not self.use_softmax:
#                     model_prob = getprobs(pred)
#                 else:
#                     model_prob = pred.clone()
#                 all_prob = torch.zeros_like(y)
#                 all_prob[:, self.label_indices] = model_prob
#                 y = y.cpu().numpy()
#                 all_prob = all_prob.cpu().numpy()
                
#                 labels.append(np.argmax(y, 1))
#                 preds.append(np.argmax(all_prob, 1))
#                 maxprobs.append(all_prob.max(axis=-1))
#                 probs.append(all_prob)
#                 if not self.use_softmax:
#                     sums.append((pred+1).sum(-1).cpu().numpy())
#                     oods.append(~idx2keep)
                
#         labels = np.concatenate(labels, axis = None)
#         preds = np.concatenate(preds, axis = None)
#         oods = np.concatenate(oods, axis = None)
#         maxprobs = np.concatenate(maxprobs, axis = None)
#         probs = np.concatenate(probs, axis = 0)
#         if not self.use_softmax:
#             sums = np.concatenate(sums, axis = None)
#             uncs = len(self.label_indices)*1.0 / sums
        
#         del test_set, testloader
        
#         return labels, preds, maxprobs, probs, sums, oods, uncs

# %%
model_results = {}

for modelname in sorted(all_models):
    # if "jetnet_nominal" in modelname:
    #     continue
    # if "topdata" in modelname:
    #     continue
    if "softmax" in modelname or "dropout" in modelname or "topdata" in modelname or "_0.1" in modelname:
        continue
    evaluator = ModelEvaluator("../model/trained_models/" + modelname)
    
    labels, preds, maxprobs, probs, sums, oods, uncs = evaluator.evaluate()
    nparams = sum(p.numel() for p in evaluator.model.parameters())
    acc = accuracy_score(labels[~oods], preds[~oods])*100    
    
    print("{} \t\t Params: {}\t Accuracy: {:.2f}%".format(evaluator.label, nparams, acc))
    model_results[evaluator.label] = {'labels' : labels, 
                                      'preds': preds, 
                                      'maxprobs': maxprobs,
                                      'sums':sums, 
                                      'oods':oods,
                                      'uncs': uncs,
                                      'probs': probs}
    if makeFile:
        f = h5py.File("RESULTS_{}.h5".format(modelname), "w")
        for key in model_results[evaluator.label].keys():
            f.create_dataset(key, data = model_results[evaluator.label][key])
        f.close()
    
    del evaluator
# Out:
# jetnet_0.5_skiptop_ocmodel 		 Params: 97008	 Accuracy: 80.80%
# jetnet_0.5_skiptwz_ocmodel 		 Params: 96806	 Accuracy: 83.51%
# jetnet_0.5_skipwz_ocmodel 		 Params: 96907	 Accuracy: 81.62%
# jetnet_0_baseline 		 Params: 97109	 Accuracy: 80.27%
# jetnet_0_skiptop 		 Params: 97008	 Accuracy: 81.46%
# jetnet_0_skiptwz 		 Params: 96806	 Accuracy: 83.65%
# jetnet_0_skipwz 		 Params: 96907	 Accuracy: 81.75%
# jetnet_nominal_baseline 		 Params: 97109	 Accuracy: 78.92%
# jetnet_nominal_baseline2 		 Params: 97109	 Accuracy: 78.38%
# jetnet_nominal_skiptop 		 Params: 97008	 Accuracy: 80.69%
# jetnet_nominal_skiptwz 		 Params: 96806	 Accuracy: 83.60%
# jetnet_nominal_skipwz 		 Params: 96907	 Accuracy: 81.54%

# %%
for key in model_results.keys():
    if '0.1' in key:
        continue
    if 'nominal_0' in key:
        continue
    if "topdata" in key:
        continue

    print(key)
    if "jetnet" in key:
        l_max = 5.1
    else:
        l_max = 2.1
    
    labels, preds, maxprobs, sums, oods, uncs = model_results[key]['labels'], model_results[key]['preds'], \
                                                model_results[key]['maxprobs'], model_results[key]['sums'], \
                                                model_results[key]['oods'], model_results[key]['uncs'],
    
    fig, axes = plt.subplots(2, 4, figsize=(6*5, 6*2), sharex = False, sharey = False)
    
    axes[0, 0].hist(uncs[~oods],
                    bins=np.arange(0.,1.01,0.04), 
                    label=key + '(~oods)', 
                    alpha = 0.7, 
                    histtype = 'step', linewidth = 3)
    axes[0, 0].set_xlabel("Uncertainty")
    axes[1, 0].hist(uncs[oods],
                    bins=np.arange(0.,1.01,0.04), 
                    label=key + '(oods)', 
                    alpha = 0.7, 
                    histtype = 'step', linewidth = 3)
    axes[1, 0].set_xlabel("Uncertainty")
    
    
    h = axes[0, 1].hist2d(maxprobs[~oods], uncs[~oods], 
                          cmap = 'winter',
                          bins = [np.arange(0.,1.01,0.04), np.arange(0.,1.01,0.04)])
    fig.colorbar(h[3], ax=axes[0, 1])
    axes[0, 1].set_xlabel("Max. Prob.")
    axes[0, 1].set_ylabel("Uncertainty")
    
    h = axes[1, 1].hist2d(maxprobs[oods], uncs[oods], 
                          cmap = 'winter',
                          bins = [np.arange(0.,1.01,0.04), np.arange(0.,1.01,0.04)])
    fig.colorbar(h[3], ax=axes[1, 1])
    axes[1, 1].set_xlabel("Max. Prob.")
    axes[1, 1].set_ylabel("Uncertainty")
    
    
    h = axes[0, 2].hist2d(labels[~oods], preds[~oods], 
                          cmap = 'winter',
                          bins = [np.arange(0.,l_max,1), np.arange(0.,l_max,1)])
    
    for i in range(len(h[2])-1):
        for j in range(len(h[1])-1):
            axes[0,2].text(h[1][j]+0.5,h[2][i]+0.5, int(h[0].T[i,j]), 
                           color="w", ha="center", va="center", fontweight="bold")

    fig.colorbar(h[3], ax=axes[0, 2])
    axes[0, 2].set_xlabel("Labels")
    axes[0, 2].set_ylabel("Preds")
    
    h = axes[1, 2].hist2d(labels[oods], preds[oods], 
                          cmap = 'winter',
                          bins = [np.arange(0.,l_max,1), np.arange(0.,l_max,1)])
    for i in range(len(h[2])-1):
        for j in range(len(h[1])-1):
            axes[1,2].text(h[1][j]+0.5,h[2][i]+0.5, int(h[0].T[i,j]), 
                           color="w", ha="center", va="center", fontweight="bold")
    fig.colorbar(h[3], ax=axes[1, 2])
    axes[1, 2].set_xlabel("Labels")
    axes[1, 2].set_ylabel("Preds")
    
    
    h = axes[0, 3].hist2d(labels[~oods], uncs[~oods] + preds[~oods] -1.e-4, 
                          cmap = 'winter',
                          bins = [np.arange(0.,l_max,1), np.arange(0.,l_max,0.2)])
    fig.colorbar(h[3], ax=axes[0, 3])
    axes[0, 3].set_xlabel("Labels")
    axes[0, 3].set_ylabel("Pred. Label + Unc.")
    for i in range(len(h[2])-1):
        for j in range(len(h[1])-1):
            axes[0,3].text(h[1][j]+0.5,h[2][i]+0.05, int(h[0].T[i,j]), 
                           color="w", ha="center", va="center", fontweight="bold")
    for jj in np.arange(1,l_max,1):
        axes[0, 3].axhline(jj)
    
    h = axes[1, 3].hist2d(labels[oods], uncs[oods] + preds[oods] -1.e-4, 
                          cmap = 'winter',
                          bins = [np.arange(0.,l_max,1), np.arange(0.,l_max,0.2)])
    fig.colorbar(h[3], ax=axes[1, 3])
    axes[1, 3].set_xlabel("Labels")
    axes[1, 3].set_ylabel("Pred. Label + Unc.")
    for i in range(len(h[2])-1):
        for j in range(len(h[1])-1):
            axes[1,3].text(h[1][j]+0.5,h[2][i]+0.05, int(h[0].T[i,j]), 
                           color="w", ha="center", va="center", fontweight="bold")
            
    for jj in np.arange(1,l_max,1):
        axes[1, 3].axhline(jj)
            
    plt.show()
# Out:
# jetnet_0.5_skiptop_ocmodel
# jetnet_0.5_skiptwz_ocmodel
# jetnet_0.5_skipwz_ocmodel
# jetnet_0_baseline
# jetnet_0_skiptop
# jetnet_0_skiptwz
# jetnet_0_skipwz
# jetnet_nominal_baseline
# jetnet_nominal_baseline2
# jetnet_nominal_skiptop
# jetnet_nominal_skiptwz
# jetnet_nominal_skipwz
